# %% [markdown]
# #DeepForest Training Walkthrough(CPU/GPU)
#   - For GPU implementation.
#       1. Select **Runtime** > Change **runtime type** and Select GPU as Hardware accelerator.

# %%
#install the package, on colab make sure to upgrade existing packages. This is not needed in a clean env.
! pip install --upgrade deepforest
# Out:
# Requirement already satisfied: deepforest in /home/christian/hnee/DeepForest (1.3.3)
# Requirement already satisfied: albumentations>=1.0.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.4.14)
# Requirement already satisfied: aiolimiter in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.1.0)
# Requirement already satisfied: aiohttp in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (3.10.5)
# Requirement already satisfied: docformatter in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.7.5)
# Requirement already satisfied: huggingface_hub in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.24.6)
# Requirement already satisfied: geopandas in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.13.2)
# Requirement already satisfied: matplotlib in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (3.7.5)
# Requirement already satisfied: nbqa in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.9.0)
# Requirement already satisfied: numpy in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.24.4)
# Requirement already satisfied: opencv-python-headless>=4.5.4 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (4.10.0.84)
# Requirement already satisfied: pandas in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (2.0.3)
# Requirement already satisfied: Pillow>6.2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (10.4.0)
# Requirement already satisfied: progressbar2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (4.4.2)
# Requirement already satisfied: pycocotools in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (2.0.7)
# Requirement already satisfied: Pygments in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (2.18.0)
# Requirement already satisfied: pytorch-lightning>=1.5.8 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (2.4.0)
# Requirement already satisfied: rasterio in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.3.10)
# Requirement already satisfied: recommonmark in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.7.1)
# Requirement already satisfied: rtree in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.3.0)
# Requirement already satisfied: scipy>1.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.10.0)
# Requirement already satisfied: six in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (1.16.0)
# Requirement already satisfied: slidingwindow in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.0.14)
# Requirement already satisfied: sphinx in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (7.1.2)
# Requirement already satisfied: supervision in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.22.0)
# Requirement already satisfied: torch in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (2.4.0)
# Requirement already satisfied: torchvision>=0.13 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.19.0)
# Requirement already satisfied: tqdm in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (4.66.5)
# Requirement already satisfied: xmltodict in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from deepforest) (0.13.0)
# Requirement already satisfied: scikit-image>=0.21.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (0.21.0)
# Requirement already satisfied: PyYAML in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (4.12.2)
# Requirement already satisfied: pydantic>=2.7.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (2.8.2)
# Requirement already satisfied: albucore>=0.0.13 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (0.0.13)
# Requirement already satisfied: eval-type-backport in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from albumentations>=1.0.0->deepforest) (0.2.0)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pytorch-lightning>=1.5.8->deepforest) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pytorch-lightning>=1.5.8->deepforest) (24.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pytorch-lightning>=1.5.8->deepforest) (0.11.6)
# Requirement already satisfied: filelock in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (3.15.4)
# Requirement already satisfied: sympy in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (1.13.2)
# Requirement already satisfied: networkx in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (3.1)
# Requirement already satisfied: jinja2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from torch->deepforest) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->deepforest) (12.6.20)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from aiohttp->deepforest) (4.0.3)
# Requirement already satisfied: charset_normalizer<4.0.0,>=3.0.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from docformatter->deepforest) (3.3.2)
# Requirement already satisfied: untokenize<0.2.0,>=0.1.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from docformatter->deepforest) (0.1.1)
# Requirement already satisfied: fiona>=1.8.19 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from geopandas->deepforest) (1.9.6)
# Requirement already satisfied: pyproj>=3.0.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from geopandas->deepforest) (3.5.0)
# Requirement already satisfied: shapely>=1.7.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from geopandas->deepforest) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pandas->deepforest) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pandas->deepforest) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pandas->deepforest) (2024.1)
# Requirement already satisfied: requests in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface_hub->deepforest) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib->deepforest) (6.4.4)
# Requirement already satisfied: autopep8>=1.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from nbqa->deepforest) (2.3.1)
# Requirement already satisfied: ipython>=7.8.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from nbqa->deepforest) (8.12.3)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from nbqa->deepforest) (6.0.0)
# Requirement already satisfied: tomli in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from nbqa->deepforest) (2.0.1)
# Requirement already satisfied: python-utils>=3.8.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from progressbar2->deepforest) (3.8.2)
# Requirement already satisfied: affine in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (2.4.0)
# Requirement already satisfied: certifi in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (2024.7.4)
# Requirement already satisfied: click>=4.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (1.4.7)
# Requirement already satisfied: click-plugins in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (1.1.1)
# Requirement already satisfied: setuptools in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (72.1.0)
# Requirement already satisfied: importlib-metadata in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from rasterio->deepforest) (8.4.0)
# Requirement already satisfied: commonmark>=0.8.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from recommonmark->deepforest) (0.9.1)
# Requirement already satisfied: docutils>=0.11 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from recommonmark->deepforest) (0.20.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.0.3)
# Requirement already satisfied: snowballstemmer>=2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (2.16.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (0.7.13)
# Requirement already satisfied: imagesize>=1.3 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sphinx->deepforest) (1.4.1)
# Requirement already satisfied: psutil in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from slidingwindow->deepforest) (6.0.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision->deepforest) (0.7.1)
# Requirement already satisfied: pycodestyle>=2.12.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from autopep8>=1.5->nbqa->deepforest) (2.12.1)
# Requirement already satisfied: zipp>=0.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from importlib-metadata->rasterio->deepforest) (3.20.1)
# Requirement already satisfied: backcall in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (0.2.0)
# Requirement already satisfied: decorator in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (0.1.7)
# Requirement already satisfied: pickleshare in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (3.0.47)
# Requirement already satisfied: stack-data in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from ipython>=7.8.0->nbqa->deepforest) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from jinja2->torch->deepforest) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pydantic>=2.7.0->albumentations>=1.0.0->deepforest) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pydantic>=2.7.0->albumentations>=1.0.0->deepforest) (2.20.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface_hub->deepforest) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface_hub->deepforest) (2.2.2)
# Requirement already satisfied: imageio>=2.27 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations>=1.0.0->deepforest) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations>=1.0.0->deepforest) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations>=1.0.0->deepforest) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations>=1.0.0->deepforest) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from sympy->torch->deepforest) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.8.0->nbqa->deepforest) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.8.0->nbqa->deepforest) (0.7.0)
# Requirement already satisfied: wcwidth in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.8.0->nbqa->deepforest) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->nbqa->deepforest) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->nbqa->deepforest) (2.4.1)
# Requirement already satisfied: pure-eval in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->nbqa->deepforest) (0.2.3)

# %%
# pip install git+https://github.com/weecology/DeepForest.git
! pip install numpy
! pip install huggingface-hub
! pip install supervision
# Out:
# Requirement already satisfied: numpy in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: huggingface-hub in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (0.24.6)
# Requirement already satisfied: filelock in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from huggingface-hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface-hub) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface-hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from requests->huggingface-hub) (2024.7.4)
# Requirement already satisfied: supervision in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (0.22.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (3.7.5)
# Requirement already satisfied: numpy>=1.21.2 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (1.24.4)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (6.0.2)
# Requirement already satisfied: scipy==1.10.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from supervision) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision) (6.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->supervision) (3.20.1)
# Requirement already satisfied: six>=1.5 in /home/christian/anaconda3/envs/DeepForest2/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.16.0)

# %%
#load the modules
import os
import time
import numpy as np
from deepforest import main
from deepforest import get_data
from deepforest import utilities
from deepforest import preprocess

# %%
#convert hand annotations from xml into retinanet format
#The get_data function is only needed when fetching sample package data
YELL_xml = get_data("2019_YELL_2_528000_4978000_image_crop2.xml")
annotation = utilities.xml_to_annotations(YELL_xml)
annotation.head()
# Out:
#                                    image_path  xmin  ymin  xmax  ymax label
# 0  2019_YELL_2_528000_4978000_image_crop2.png   681   369   699   386  Tree
# 1  2019_YELL_2_528000_4978000_image_crop2.png   980    59   998    79  Tree
# 2  2019_YELL_2_528000_4978000_image_crop2.png   953   135   964   150  Tree
# 3  2019_YELL_2_528000_4978000_image_crop2.png   969   183   995   208  Tree
# 4  2019_YELL_2_528000_4978000_image_crop2.png   742   623   751   635  Tree

# %%
#load the image file corresponding to the annotaion file
YELL_train = get_data("2019_YELL_2_528000_4978000_image_crop2.png")
image_path = os.path.dirname(YELL_train)
#Write converted dataframe to file. Saved alongside the images
annotation.to_csv(os.path.join(image_path, "train_example.csv"), index=False)

# %% [markdown]
# ## Prepare Training and Validation Data
#   - 75% Training Data
#   - 25% Validation Data

# %%
#Find annotation path
annotation_path = os.path.join(image_path,"train_example.csv")
#crop images will save in a newly created directory
#os.mkdir(os.getcwd(),'train_data_folder')
crop_dir = os.path.join(os.getcwd(),'train_data_folder_tree')
train_annotations= preprocess.split_raster(path_to_raster=YELL_train,
                                 annotations_file=annotation_path,
                                 base_dir=crop_dir,
                                 patch_size=400,
                                 patch_overlap=0.05)
# Out:
# NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#Split image crops into training and test. Normally these would be different tiles! Just as an example.
image_paths = train_annotations.image_path.unique()
#split 25% validation annotation
valid_paths = np.random.choice(image_paths, int(len(image_paths)*0.25) )
valid_annotations = train_annotations.loc[train_annotations.image_path.isin(valid_paths)]
train_annotations = train_annotations.loc[~train_annotations.image_path.isin(valid_paths)]

print(image_paths)
# Out:
# ['2019_YELL_2_528000_4978000_image_crop2_1.png'
#  '2019_YELL_2_528000_4978000_image_crop2_3.png'
#  '2019_YELL_2_528000_4978000_image_crop2_4.png'
#  '2019_YELL_2_528000_4978000_image_crop2_5.png'
#  '2019_YELL_2_528000_4978000_image_crop2_6.png'
#  '2019_YELL_2_528000_4978000_image_crop2_7.png'
#  '2019_YELL_2_528000_4978000_image_crop2_8.png'
#  '2019_YELL_2_528000_4978000_image_crop2_9.png'
#  '2019_YELL_2_528000_4978000_image_crop2_10.png'
#  '2019_YELL_2_528000_4978000_image_crop2_11.png'
#  '2019_YELL_2_528000_4978000_image_crop2_12.png'
#  '2019_YELL_2_528000_4978000_image_crop2_13.png'
#  '2019_YELL_2_528000_4978000_image_crop2_14.png'
#  '2019_YELL_2_528000_4978000_image_crop2_15.png'
#  '2019_YELL_2_528000_4978000_image_crop2_16.png'
#  '2019_YELL_2_528000_4978000_image_crop2_17.png'
#  '2019_YELL_2_528000_4978000_image_crop2_18.png'
#  '2019_YELL_2_528000_4978000_image_crop2_19.png'
#  '2019_YELL_2_528000_4978000_image_crop2_20.png'
#  '2019_YELL_2_528000_4978000_image_crop2_21.png'
#  '2019_YELL_2_528000_4978000_image_crop2_22.png'
#  '2019_YELL_2_528000_4978000_image_crop2_23.png'
#  '2019_YELL_2_528000_4978000_image_crop2_24.png'
#  '2019_YELL_2_528000_4978000_image_crop2_25.png'
#  '2019_YELL_2_528000_4978000_image_crop2_26.png'
#  '2019_YELL_2_528000_4978000_image_crop2_27.png'
#  '2019_YELL_2_528000_4978000_image_crop2_28.png'
#  '2019_YELL_2_528000_4978000_image_crop2_29.png'
#  '2019_YELL_2_528000_4978000_image_crop2_30.png'
#  '2019_YELL_2_528000_4978000_image_crop2_31.png'
#  '2019_YELL_2_528000_4978000_image_crop2_32.png'
#  '2019_YELL_2_528000_4978000_image_crop2_33.png'
#  '2019_YELL_2_528000_4978000_image_crop2_34.png'
#  '2019_YELL_2_528000_4978000_image_crop2_35.png'
#  '2019_YELL_2_528000_4978000_image_crop2_36.png'
#  '2019_YELL_2_528000_4978000_image_crop2_37.png'
#  '2019_YELL_2_528000_4978000_image_crop2_38.png'
#  '2019_YELL_2_528000_4978000_image_crop2_39.png'
#  '2019_YELL_2_528000_4978000_image_crop2_40.png'
#  '2019_YELL_2_528000_4978000_image_crop2_41.png']

# %%
#View output
train_annotations.head()
print("There are {} training crown annotations".format(train_annotations.shape[0]))
print("There are {} test crown annotations".format(valid_annotations.shape[0]))

#save to file and create the file dir
annotations_file= os.path.join(crop_dir,"train.csv")
validation_file= os.path.join(crop_dir,"valid.csv")
#Write window annotations file without a header row, same location as the "base_dir" above.
train_annotations.to_csv(annotations_file,index=False)
valid_annotations.to_csv(validation_file,index=False)
# Out:
# There are 519 training crown annotations
# There are 173 test crown annotations

# %%
annotations_file
# Out:
# '/home/christian/hnee/DeepForest/docs/examples/train_data_folder_tree/train.csv'

# %%
train_annotations.head()
# Out:
#                                        image_path   xmin   ymin   xmax   ymax  \
# 28   2019_YELL_2_528000_4978000_image_crop2_1.png  195.0  115.0  238.0  158.0
# 29   2019_YELL_2_528000_4978000_image_crop2_3.png  336.0  152.0  383.0  189.0
# 477  2019_YELL_2_528000_4978000_image_crop2_4.png  371.0   50.0  400.0  110.0
# 232  2019_YELL_2_528000_4978000_image_crop2_4.png  311.0   91.0  348.0  135.0
# 231  2019_YELL_2_528000_4978000_image_crop2_4.png  272.0  101.0  312.0  148.0
#
#     label                                           geometry
# 28   Tree  POLYGON ((195.000 115.000, 195.000 158.000, 23...
# 29   Tree  POLYGON ((336.000 152.000, 336.000 189.000, 38...
# 477  Tree  POLYGON ((371.000 50.000, 371.000 110.000, 400...
# 232  Tree  POLYGON ((311.000 91.000, 311.000 135.000, 348...
# 231  Tree  POLYGON ((272.000 101.000, 272.000 148.000, 31...

# %%
valid_annotations.head()
# Out:
#                                         image_path   xmin   ymin   xmax  \
# 433  2019_YELL_2_528000_4978000_image_crop2_14.png   43.0    3.0   78.0
# 170  2019_YELL_2_528000_4978000_image_crop2_14.png    0.0    1.0   26.0
# 432  2019_YELL_2_528000_4978000_image_crop2_14.png   52.0   29.0   73.0
# 350  2019_YELL_2_528000_4978000_image_crop2_14.png   15.0   48.0   48.0
# 440  2019_YELL_2_528000_4978000_image_crop2_14.png  158.0  172.0  180.0
#
#       ymax label                                           geometry
# 433   31.0  Tree  POLYGON ((43.000 3.000, 43.000 31.000, 78.000 ...
# 170   36.0  Tree  POLYGON ((26.000 36.000, 26.000 1.000, 0.000 1...
# 432   46.0  Tree  POLYGON ((52.000 29.000, 52.000 46.000, 73.000...
# 350   87.0  Tree  POLYGON ((15.000 48.000, 15.000 87.000, 48.000...
# 440  196.0  Tree  POLYGON ((158.000 172.000, 158.000 196.000, 18...

# %% [markdown]
# ## Training & Evaluating Using GPU

# %%
validation_file
# Out:
# '/home/christian/hnee/DeepForest/docs/examples/train_data_folder_tree/valid.csv'

# %%
annotations_file
# Out:
# '/home/christian/hnee/DeepForest/docs/examples/train_data_folder_tree/train.csv'

# %%
# annotations_file = "/home/christian/hnee/DeepForest/docs/examples/train_data_folder/train.csv"
# validation_file = "/home/christian/hnee/DeepForest/docs/examples/train_data_folder/train.csv"

# %%
#initial the model and change the corresponding config file

m = main.deepforest(label_dict={"Tree": 0})

m.config["batch_size"] = 20
m.config["epochs"] = 30

m.config['gpus'] = '-1' #move to GPU and use all the GPU resources
m.config["train"]["csv_file"] = annotations_file
m.config["train"]["root_dir"] = os.path.dirname(annotations_file)


m.config["score_thresh"] = 0.4
m.config["train"]['epochs'] = 25

m.config["validation"]["csv_file"] = annotations_file
m.config["validation"]["root_dir"] = os.path.dirname(annotations_file)

#create a pytorch lighting trainer used to training
m.create_trainer()
#load the lastest release model
# m.use_release()
# Out:
# Reading config file: /home/christian/hnee/DeepForest/deepforest/data/deepforest_config.yml
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..

# %%
""" FIXME this fails sometimes with UserWarning: Converting predictions to GeoDataFrame using geometry column

No predictions made

File ~/anaconda3/envs/DeepForest2/lib/python3.8/site-packages/pytorch_lightning/trainer/call.py:167, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
    164 pl_module._current_fx_name = hook_name
    166 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
--> 167     output = fn(*args, **kwargs)
    169 # restore current_fx when nested context
    170 pl_module._current_fx_name = prev_fx_name

File ~/hnee/DeepForest/deepforest/main.py:654, in deepforest.on_validation_epoch_end(self)
    652 for key, value in results.items():
    653     if key in ["class_recall"]:
--> 654         for index, row in value.iterrows():
    655             self.log(
    656                 "{}_Recall".format(
    657                     self.numeric_to_label_dict[row["label"]]),
    658                 row["recall"])
    659             self.log(
    660                 "{}_Precision".format(
    661                     self.numeric_to_label_dict[row["label"]]),
    662                 row["precision"])

"""

"""
TODO: why is this always creating an weird error at epoch 20?



"""

start_time = time.time()
m.trainer.fit(m)
print(f"--- Training on GPU: {(time.time() - start_time):.2f} seconds ---")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#       1 """ FIXME this fails sometimes with UserWarning: Converting predictions to GeoDataFrame using geometry column
#       2
#       3 No predictions made
#    (...)
#      24
#      25 """
#      27 """
#      28 TODO: why is this always creating an weird error at epoch 20?
#      29
#      30
#      31
#      32 """
# ---> 34 start_time = time.time()
#      35 m.trainer.fit(m)
#      36 print(f"--- Training on GPU: {(time.time() - start_time):.2f} seconds ---")
#
# NameError: name 'time' is not defined

# %%
#save the prediction result to a prediction folder
save_dir = os.path.join(os.getcwd(),'pred_result')
try:
  os.mkdir(save_dir)
except FileExistsError:
  pass
results = m.evaluate(annotations_file, os.path.dirname(annotations_file), iou_threshold = 0.4, savedir= save_dir)

# %%
results

# %%
results['box_precision']

# %%
results["box_recall"]

# %%
results["results"]

# %%
# results["class_recall"] #useless with a single class

# %%
import torch
root_folder = os.path.join(os.getcwd(), "model")

m.trainer.save_checkpoint(
    os.path.join(root_folder, "checkpoint_epochs_10_cosine_lr_retinanet.pl")
)
torch.save(m.model.state_dict(), os.path.join(root_folder, "weights_cosine_lr"))

# %%
# Load from the saved checkpoint
model = main.deepforest.load_from_checkpoint(
    os.path.join(root_folder, "checkpoint_epochs_10_cosine_lr_retinanet.pl")
)

# %%
import matplotlib.pyplot as plt

# %%
raster_path = "/home/christian/hnee/DeepForest/deepforest/data/2019_YELL_2_541000_4977000_image_crop.png"
raster_path = "/home/christian/hnee/DeepForest/deepforest/data/2018_SJER_3_252000_4107000_image_477.tif"
raster_path = "/home/christian/hnee/DeepForest/deepforest/data/2019_YELL_2_528000_4978000_image_crop2.png"
predicted_raster = model.predict_tile(
    raster_path, return_plot=True, patch_size=400, patch_overlap=0.25
)
plt.imshow(predicted_raster)
plt.show()
